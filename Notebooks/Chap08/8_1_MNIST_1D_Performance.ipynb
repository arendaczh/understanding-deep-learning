# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-uuvh2b57
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-uuvh2b57
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.1.1)
# Requirement already satisfied: matplotlib in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (3.10.7)
# Requirement already satisfied: scipy in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/arendaczh/Desktop/TCS/TCS-3/AI/udlbook/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=59def1365d2b685b1f323fdbf626e50aee3bb1a386c731dc2bf3a3bd61220f92
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kizznz8m/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
#   Attempting uninstall: mnist1d
#     Found existing installation: mnist1d 0.0.2.post1
#     Uninstalling mnist1d-0.0.2.post1:
#       Successfully uninstalled mnist1d-0.0.2.post1
# Successfully installed mnist1d-0.0.2.post16
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o));


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 40
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.595418, train error 63.17,  test loss 1.671344, test error 67.88
# Epoch     1, train loss 1.317873, train error 49.30,  test loss 1.463284, test error 57.40
# Epoch     2, train loss 1.136933, train error 41.38,  test loss 1.330825, test error 51.35
# Epoch     3, train loss 1.061050, train error 39.05,  test loss 1.307636, test error 49.75
# Epoch     4, train loss 0.911226, train error 32.62,  test loss 1.207353, test error 45.25
# Epoch     5, train loss 0.802090, train error 28.68,  test loss 1.151500, test error 44.17
# Epoch     6, train loss 0.727697, train error 26.07,  test loss 1.131295, test error 43.08
# Epoch     7, train loss 0.675905, train error 23.32,  test loss 1.146263, test error 42.25
# Epoch     8, train loss 0.598604, train error 20.38,  test loss 1.105003, test error 40.70
# Epoch     9, train loss 0.561986, train error 20.30,  test loss 1.117130, test error 40.10
# Epoch    10, train loss 0.430065, train error 12.43,  test loss 1.047321, test error 38.60
# Epoch    11, train loss 0.393836, train error 10.82,  test loss 1.047319, test error 37.62
# Epoch    12, train loss 0.370204, train error 10.47,  test loss 1.067450, test error 37.38
# Epoch    13, train loss 0.353288, train error 10.28,  test loss 1.080949, test error 37.90
# Epoch    14, train loss 0.312388, train error 8.00,  test loss 1.067112, test error 37.22
# Epoch    15, train loss 0.302617, train error 8.45,  test loss 1.095906, test error 36.60
# Epoch    16, train loss 0.262506, train error 6.25,  test loss 1.099844, test error 36.38
# Epoch    17, train loss 0.238134, train error 5.53,  test loss 1.112321, test error 36.60
# Epoch    18, train loss 0.213992, train error 4.15,  test loss 1.128774, test error 36.88
# Epoch    19, train loss 0.197304, train error 3.47,  test loss 1.159934, test error 36.85
# Epoch    20, train loss 0.166522, train error 2.03,  test loss 1.135088, test error 35.93
# Epoch    21, train loss 0.159133, train error 1.88,  test loss 1.140182, test error 36.10
# Epoch    22, train loss 0.150244, train error 1.38,  test loss 1.160025, test error 35.95
# Epoch    23, train loss 0.142270, train error 1.32,  test loss 1.165667, test error 36.55
# Epoch    24, train loss 0.137159, train error 1.07,  test loss 1.191040, test error 36.85
# Epoch    25, train loss 0.128524, train error 1.05,  test loss 1.191029, test error 36.85
# Epoch    26, train loss 0.122563, train error 0.88,  test loss 1.195814, test error 35.90
# Epoch    27, train loss 0.115144, train error 0.65,  test loss 1.213560, test error 36.35
# Epoch    28, train loss 0.107272, train error 0.45,  test loss 1.218854, test error 36.20
# Epoch    29, train loss 0.103714, train error 0.50,  test loss 1.234956, test error 36.00
# Epoch    30, train loss 0.099616, train error 0.40,  test loss 1.243069, test error 36.50
# Epoch    31, train loss 0.095413, train error 0.28,  test loss 1.243589, test error 36.62
# Epoch    32, train loss 0.093107, train error 0.25,  test loss 1.244677, test error 36.00
# Epoch    33, train loss 0.090819, train error 0.18,  test loss 1.252528, test error 36.42
# Epoch    34, train loss 0.089135, train error 0.18,  test loss 1.258021, test error 36.45
# Epoch    35, train loss 0.087543, train error 0.22,  test loss 1.260478, test error 36.50
# Epoch    36, train loss 0.084748, train error 0.12,  test loss 1.268988, test error 36.45
# Epoch    37, train loss 0.082653, train error 0.07,  test loss 1.277297, test error 36.50
# Epoch    38, train loss 0.080871, train error 0.12,  test loss 1.280916, test error 36.35
# Epoch    39, train loss 0.079500, train error 0.07,  test loss 1.287848, test error 36.72

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
