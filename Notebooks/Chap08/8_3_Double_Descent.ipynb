# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-mt_hr7yn
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-mt_hr7yn
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /home/arendaczh/micromamba/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /home/arendaczh/micromamba/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /home/arendaczh/micromamba/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (3.9.4)
# Requirement already satisfied: scipy in /home/arendaczh/micromamba/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (6.4.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (2024.12.14)
# Requirement already satisfied: zipp>=3.1.0 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->mnist1d==0.0.2.post16) (3.21.0)
# Requirement already satisfied: six>=1.5 in /home/arendaczh/micromamba/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.294659, train error 87.47,  test loss 2.289593, test error 87.15
# Epoch   100, train loss 1.893143, train error 72.50,  test loss 1.731183, test error 69.15
# Epoch   200, train loss 1.866892, train error 71.45,  test loss 1.707451, test error 68.12
# Epoch   300, train loss 1.865801, train error 71.70,  test loss 1.693677, test error 68.82
# Epoch   400, train loss 1.855790, train error 70.57,  test loss 1.701503, test error 67.90
# Epoch   500, train loss 1.850803, train error 70.88,  test loss 1.698422, test error 67.43
# Epoch   600, train loss 1.849049, train error 70.68,  test loss 1.707160, test error 68.28
# Epoch   700, train loss 1.849579, train error 70.32,  test loss 1.701938, test error 67.82
# Epoch   800, train loss 1.846691, train error 70.35,  test loss 1.690360, test error 67.93
# Epoch   900, train loss 1.848043, train error 70.05,  test loss 1.703218, test error 67.97
# Training model with   4 hidden variables
# Epoch     0, train loss 2.285183, train error 88.10,  test loss 2.279583, test error 86.62
# Epoch   100, train loss 1.822780, train error 68.10,  test loss 1.643270, test error 64.93
# Epoch   200, train loss 1.724464, train error 62.97,  test loss 1.530234, test error 58.90
# Epoch   300, train loss 1.716945, train error 62.78,  test loss 1.542051, test error 59.90
# Epoch   400, train loss 1.710422, train error 62.30,  test loss 1.523330, test error 59.58
# Epoch   500, train loss 1.708988, train error 62.95,  test loss 1.542281, test error 61.15
# Epoch   600, train loss 1.704780, train error 62.60,  test loss 1.524141, test error 60.65
# Epoch   700, train loss 1.706737, train error 61.83,  test loss 1.514011, test error 59.85
# Epoch   800, train loss 1.706174, train error 61.83,  test loss 1.511086, test error 59.60
# Epoch   900, train loss 1.706424, train error 61.92,  test loss 1.510972, test error 59.92
# Training model with   6 hidden variables
# Epoch     0, train loss 2.262221, train error 84.20,  test loss 2.264143, test error 85.25
# Epoch   100, train loss 1.636720, train error 58.22,  test loss 1.459864, test error 55.80
# Epoch   200, train loss 1.600517, train error 57.58,  test loss 1.451791, test error 56.00
# Epoch   300, train loss 1.589756, train error 56.72,  test loss 1.452382, test error 55.47
# Epoch   400, train loss 1.594485, train error 58.17,  test loss 1.472415, test error 56.28
# Epoch   500, train loss 1.580681, train error 56.72,  test loss 1.457614, test error 55.72
# Epoch   600, train loss 1.581346, train error 56.45,  test loss 1.457134, test error 56.50
# Epoch   700, train loss 1.577675, train error 56.88,  test loss 1.465133, test error 56.25
# Epoch   800, train loss 1.575030, train error 56.55,  test loss 1.464381, test error 56.88
# Epoch   900, train loss 1.577104, train error 57.15,  test loss 1.461854, test error 56.28
# Training model with   8 hidden variables
# Epoch     0, train loss 2.248336, train error 84.78,  test loss 2.227819, test error 84.10
# Epoch   100, train loss 1.615829, train error 57.12,  test loss 1.456851, test error 55.12
# Epoch   200, train loss 1.560417, train error 54.50,  test loss 1.415609, test error 53.03
# Epoch   300, train loss 1.543597, train error 53.60,  test loss 1.414714, test error 52.45
# Epoch   400, train loss 1.533347, train error 53.40,  test loss 1.409867, test error 52.50
# Epoch   500, train loss 1.534649, train error 53.78,  test loss 1.423078, test error 53.33
# Epoch   600, train loss 1.530549, train error 53.50,  test loss 1.422976, test error 52.65
# Epoch   700, train loss 1.531812, train error 53.55,  test loss 1.428047, test error 52.67
# Epoch   800, train loss 1.519100, train error 53.17,  test loss 1.410465, test error 52.62
# Epoch   900, train loss 1.522919, train error 53.05,  test loss 1.419489, test error 52.78
# Training model with  10 hidden variables
# Epoch     0, train loss 2.240630, train error 84.82,  test loss 2.235228, test error 84.38
# Epoch   100, train loss 1.508256, train error 52.17,  test loss 1.359726, test error 50.75
# Epoch   200, train loss 1.475391, train error 51.72,  test loss 1.375606, test error 52.70
# Epoch   300, train loss 1.458051, train error 50.30,  test loss 1.379445, test error 51.60
# Epoch   400, train loss 1.444743, train error 49.15,  test loss 1.387083, test error 51.42
# Epoch   500, train loss 1.441335, train error 49.92,  test loss 1.398947, test error 52.30
# Epoch   600, train loss 1.435339, train error 49.03,  test loss 1.403543, test error 52.25
# Epoch   700, train loss 1.431560, train error 48.62,  test loss 1.404868, test error 52.62
# Epoch   800, train loss 1.425092, train error 48.20,  test loss 1.398066, test error 52.10
# Epoch   900, train loss 1.423885, train error 48.28,  test loss 1.399650, test error 52.15
# Training model with  14 hidden variables
# Epoch     0, train loss 2.199691, train error 83.43,  test loss 2.175012, test error 83.85
# Epoch   100, train loss 1.509251, train error 52.60,  test loss 1.436659, test error 54.95
# Epoch   200, train loss 1.397306, train error 47.70,  test loss 1.366061, test error 51.28
# Epoch   300, train loss 1.350413, train error 46.12,  test loss 1.372954, test error 50.38
# Epoch   400, train loss 1.328819, train error 45.62,  test loss 1.379810, test error 50.78
# Epoch   500, train loss 1.315005, train error 45.30,  test loss 1.415879, test error 51.50
# Epoch   600, train loss 1.301418, train error 44.35,  test loss 1.443943, test error 52.05
# Epoch   700, train loss 1.295483, train error 43.90,  test loss 1.459763, test error 51.95
# Epoch   800, train loss 1.290051, train error 43.78,  test loss 1.511044, test error 53.03
# Epoch   900, train loss 1.289775, train error 44.12,  test loss 1.499129, test error 52.83
# Training model with  18 hidden variables
# Epoch     0, train loss 2.127414, train error 79.43,  test loss 2.077993, test error 78.47
# Epoch   100, train loss 1.345836, train error 44.50,  test loss 1.282573, test error 48.05
# Epoch   200, train loss 1.252238, train error 42.17,  test loss 1.298693, test error 47.60
# Epoch   300, train loss 1.197566, train error 39.62,  test loss 1.329874, test error 47.60
# Epoch   400, train loss 1.174263, train error 38.92,  test loss 1.389674, test error 48.45
# Epoch   500, train loss 1.148608, train error 37.70,  test loss 1.420067, test error 48.62
# Epoch   600, train loss 1.140576, train error 38.28,  test loss 1.459823, test error 49.12
# Epoch   700, train loss 1.117642, train error 37.92,  test loss 1.491470, test error 49.88
# Epoch   800, train loss 1.113855, train error 37.80,  test loss 1.528080, test error 50.28
# Epoch   900, train loss 1.102106, train error 37.35,  test loss 1.562815, test error 50.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.179888, train error 81.50,  test loss 2.163026, test error 81.25
# Epoch   100, train loss 1.272222, train error 42.03,  test loss 1.300360, test error 48.00
# Epoch   200, train loss 1.144580, train error 37.92,  test loss 1.353402, test error 48.97
# Epoch   300, train loss 1.098089, train error 37.22,  test loss 1.432129, test error 50.08
# Epoch   400, train loss 1.055338, train error 36.33,  test loss 1.485842, test error 51.75
# Epoch   500, train loss 1.038638, train error 36.05,  test loss 1.550678, test error 52.10
# Epoch   600, train loss 1.022002, train error 35.43,  test loss 1.584563, test error 52.47
# Epoch   700, train loss 1.007427, train error 35.57,  test loss 1.623448, test error 52.92
# Epoch   800, train loss 0.997779, train error 34.88,  test loss 1.659881, test error 53.08
# Epoch   900, train loss 0.995854, train error 34.90,  test loss 1.691670, test error 53.05
# Training model with  26 hidden variables
# Epoch     0, train loss 2.125755, train error 79.53,  test loss 2.084833, test error 78.90
# Epoch   100, train loss 1.161549, train error 38.50,  test loss 1.316220, test error 49.12
# Epoch   200, train loss 0.988662, train error 32.43,  test loss 1.424191, test error 50.03
# Epoch   300, train loss 0.930974, train error 32.05,  test loss 1.579289, test error 49.95
# Epoch   400, train loss 0.874718, train error 29.15,  test loss 1.682874, test error 50.95
# Epoch   500, train loss 0.843617, train error 28.15,  test loss 1.781969, test error 52.38
# Epoch   600, train loss 0.827025, train error 27.45,  test loss 1.875697, test error 53.03
# Epoch   700, train loss 0.820501, train error 27.40,  test loss 1.953573, test error 53.22
# Epoch   800, train loss 0.803761, train error 27.30,  test loss 2.000790, test error 53.50
# Epoch   900, train loss 0.779796, train error 26.62,  test loss 2.031658, test error 53.58
# Training model with  30 hidden variables
# Epoch     0, train loss 2.120571, train error 78.07,  test loss 2.090885, test error 77.80
# Epoch   100, train loss 1.120928, train error 36.78,  test loss 1.327821, test error 48.70
# Epoch   200, train loss 0.955628, train error 32.07,  test loss 1.483398, test error 50.05
# Epoch   300, train loss 0.873120, train error 29.40,  test loss 1.671280, test error 51.92
# Epoch   400, train loss 0.810756, train error 27.20,  test loss 1.814738, test error 52.20
# Epoch   500, train loss 0.777817, train error 27.55,  test loss 2.014995, test error 53.50
# Epoch   600, train loss 0.759964, train error 25.85,  test loss 2.126391, test error 54.20
# Epoch   700, train loss 0.723028, train error 24.25,  test loss 2.283261, test error 54.70
# Epoch   800, train loss 0.717748, train error 24.68,  test loss 2.435831, test error 54.38
# Epoch   900, train loss 0.689809, train error 23.25,  test loss 2.547639, test error 54.88
# Training model with  35 hidden variables
# Epoch     0, train loss 2.159986, train error 79.45,  test loss 2.136932, test error 79.20
# Epoch   100, train loss 1.005327, train error 32.60,  test loss 1.414290, test error 50.10
# Epoch   200, train loss 0.770847, train error 24.80,  test loss 1.717819, test error 51.65
# Epoch   300, train loss 0.658160, train error 21.82,  test loss 2.193431, test error 53.20
# Epoch   400, train loss 0.561510, train error 18.32,  test loss 2.555886, test error 54.05
# Epoch   500, train loss 0.504836, train error 16.90,  test loss 2.885462, test error 53.90
# Epoch   600, train loss 0.479816, train error 16.60,  test loss 3.260854, test error 55.22
# Epoch   700, train loss 0.467214, train error 16.50,  test loss 3.578925, test error 56.50
# Epoch   800, train loss 0.426046, train error 14.40,  test loss 3.900562, test error 54.95
# Epoch   900, train loss 0.408636, train error 14.03,  test loss 4.158935, test error 54.85
# Training model with  40 hidden variables
# Epoch     0, train loss 2.097660, train error 78.53,  test loss 2.058769, test error 78.00
# Epoch   100, train loss 0.902393, train error 29.80,  test loss 1.437258, test error 49.88
# Epoch   200, train loss 0.644969, train error 21.45,  test loss 1.941440, test error 50.88
# Epoch   300, train loss 0.483222, train error 16.00,  test loss 2.557448, test error 53.47
# Epoch   400, train loss 0.369917, train error 12.18,  test loss 3.239638, test error 54.15
# Epoch   500, train loss 0.328348, train error 11.30,  test loss 4.058884, test error 55.78
# Epoch   600, train loss 0.265537, train error 8.95,  test loss 4.679331, test error 55.75
# Epoch   700, train loss 0.241912, train error 8.12,  test loss 5.472584, test error 56.20
# Epoch   800, train loss 0.274951, train error 9.85,  test loss 6.154588, test error 55.62
# Epoch   900, train loss 0.217335, train error 7.85,  test loss 6.824541, test error 55.85
# Training model with  45 hidden variables
# Epoch     0, train loss 2.082893, train error 77.38,  test loss 2.057270, test error 77.75
# Epoch   100, train loss 0.830134, train error 26.05,  test loss 1.534763, test error 51.38
# Epoch   200, train loss 0.499949, train error 15.95,  test loss 2.269894, test error 54.40
# Epoch   300, train loss 0.319452, train error 10.53,  test loss 3.213342, test error 54.47
# Epoch   400, train loss 0.212241, train error 6.50,  test loss 4.457479, test error 56.47
# Epoch   500, train loss 0.154906, train error 4.30,  test loss 5.753078, test error 56.65
# Epoch   600, train loss 0.116997, train error 3.43,  test loss 6.979827, test error 57.03
# Epoch   700, train loss 0.012871, train error 0.00,  test loss 8.100965, test error 57.20
# Epoch   800, train loss 0.008074, train error 0.00,  test loss 8.814163, test error 57.35
# Epoch   900, train loss 0.006029, train error 0.00,  test loss 9.317561, test error 57.45
# Training model with  50 hidden variables
# Epoch     0, train loss 2.078164, train error 78.07,  test loss 2.016738, test error 76.72
# Epoch   100, train loss 0.694627, train error 21.60,  test loss 1.612527, test error 51.15
# Epoch   200, train loss 0.321907, train error 9.15,  test loss 2.727056, test error 54.15
# Epoch   300, train loss 0.130936, train error 2.60,  test loss 4.368634, test error 54.97
# Epoch   400, train loss 0.032835, train error 0.03,  test loss 5.944933, test error 55.65
# Epoch   500, train loss 0.014151, train error 0.00,  test loss 6.956984, test error 55.78
# Epoch   600, train loss 0.008822, train error 0.00,  test loss 7.618600, test error 55.85
# Epoch   700, train loss 0.006311, train error 0.00,  test loss 8.132038, test error 56.05
# Epoch   800, train loss 0.004820, train error 0.00,  test loss 8.526967, test error 56.03
# Epoch   900, train loss 0.003881, train error 0.00,  test loss 8.851146, test error 56.15
# Training model with  55 hidden variables
# Epoch     0, train loss 2.053667, train error 76.18,  test loss 1.997099, test error 75.05
# Epoch   100, train loss 0.620468, train error 18.47,  test loss 1.625787, test error 51.10
# Epoch   200, train loss 0.196142, train error 3.95,  test loss 3.050423, test error 54.33
# Epoch   300, train loss 0.037793, train error 0.05,  test loss 4.743761, test error 55.22
# Epoch   400, train loss 0.013669, train error 0.00,  test loss 5.710514, test error 55.12
# Epoch   500, train loss 0.008147, train error 0.00,  test loss 6.319896, test error 55.40
# Epoch   600, train loss 0.005528, train error 0.00,  test loss 6.740939, test error 55.67
# Epoch   700, train loss 0.004156, train error 0.00,  test loss 7.073027, test error 55.40
# Epoch   800, train loss 0.003296, train error 0.00,  test loss 7.344633, test error 55.47
# Epoch   900, train loss 0.002712, train error 0.00,  test loss 7.576207, test error 55.33
# Training model with  60 hidden variables
# Epoch     0, train loss 2.042232, train error 75.95,  test loss 1.990639, test error 75.82
# Epoch   100, train loss 0.558997, train error 16.62,  test loss 1.794306, test error 52.62
# Epoch   200, train loss 0.116952, train error 1.20,  test loss 3.469911, test error 55.78
# Epoch   300, train loss 0.022616, train error 0.00,  test loss 4.960025, test error 56.22
# Epoch   400, train loss 0.010539, train error 0.00,  test loss 5.740483, test error 56.28
# Epoch   500, train loss 0.006556, train error 0.00,  test loss 6.251588, test error 56.50
# Epoch   600, train loss 0.004674, train error 0.00,  test loss 6.622886, test error 56.42
# Epoch   700, train loss 0.003562, train error 0.00,  test loss 6.920887, test error 56.62
# Epoch   800, train loss 0.002842, train error 0.00,  test loss 7.165585, test error 56.83
# Epoch   900, train loss 0.002355, train error 0.00,  test loss 7.376208, test error 56.67
# Training model with  70 hidden variables
# Epoch     0, train loss 2.023471, train error 75.18,  test loss 1.982862, test error 76.07
# Epoch   100, train loss 0.348444, train error 8.72,  test loss 1.940621, test error 52.00
# Epoch   200, train loss 0.031270, train error 0.00,  test loss 3.488952, test error 52.53
# Epoch   300, train loss 0.010872, train error 0.00,  test loss 4.247112, test error 53.28
# Epoch   400, train loss 0.006065, train error 0.00,  test loss 4.666049, test error 53.28
# Epoch   500, train loss 0.004095, train error 0.00,  test loss 4.965428, test error 53.45
# Epoch   600, train loss 0.003031, train error 0.00,  test loss 5.189994, test error 53.50
# Epoch   700, train loss 0.002384, train error 0.00,  test loss 5.375687, test error 53.47
# Epoch   800, train loss 0.001949, train error 0.00,  test loss 5.528583, test error 53.42
# Epoch   900, train loss 0.001640, train error 0.00,  test loss 5.663093, test error 53.38
# Training model with  80 hidden variables
# Epoch     0, train loss 2.043522, train error 76.28,  test loss 1.992758, test error 75.70
# Epoch   100, train loss 0.239558, train error 4.43,  test loss 2.047870, test error 51.42
# Epoch   200, train loss 0.020951, train error 0.00,  test loss 3.453733, test error 53.12
# Epoch   300, train loss 0.008154, train error 0.00,  test loss 4.023737, test error 53.10
# Epoch   400, train loss 0.004797, train error 0.00,  test loss 4.366801, test error 53.12
# Epoch   500, train loss 0.003305, train error 0.00,  test loss 4.608006, test error 53.33
# Epoch   600, train loss 0.002485, train error 0.00,  test loss 4.793076, test error 53.22
# Epoch   700, train loss 0.001971, train error 0.00,  test loss 4.944544, test error 53.33
# Epoch   800, train loss 0.001621, train error 0.00,  test loss 5.075855, test error 53.30
# Epoch   900, train loss 0.001370, train error 0.00,  test loss 5.186181, test error 53.35
# Training model with  90 hidden variables
# Epoch     0, train loss 1.980435, train error 73.57,  test loss 1.909709, test error 74.00
# Epoch   100, train loss 0.133523, train error 0.62,  test loss 2.305215, test error 52.35
# Epoch   200, train loss 0.014446, train error 0.00,  test loss 3.406480, test error 53.03
# Epoch   300, train loss 0.006428, train error 0.00,  test loss 3.855758, test error 53.22
# Epoch   400, train loss 0.003919, train error 0.00,  test loss 4.136790, test error 53.35
# Epoch   500, train loss 0.002761, train error 0.00,  test loss 4.336373, test error 53.30
# Epoch   600, train loss 0.002101, train error 0.00,  test loss 4.488936, test error 53.33
# Epoch   700, train loss 0.001681, train error 0.00,  test loss 4.617980, test error 53.33
# Epoch   800, train loss 0.001391, train error 0.00,  test loss 4.725491, test error 53.17
# Epoch   900, train loss 0.001182, train error 0.00,  test loss 4.820690, test error 53.17
# Training model with 100 hidden variables
# Epoch     0, train loss 1.976669, train error 73.10,  test loss 1.925926, test error 74.70
# Epoch   100, train loss 0.096291, train error 0.30,  test loss 2.305353, test error 51.03
# Epoch   200, train loss 0.012362, train error 0.00,  test loss 3.170651, test error 50.78
# Epoch   300, train loss 0.005709, train error 0.00,  test loss 3.536017, test error 51.05
# Epoch   400, train loss 0.003552, train error 0.00,  test loss 3.766342, test error 51.03
# Epoch   500, train loss 0.002524, train error 0.00,  test loss 3.932096, test error 51.10
# Epoch   600, train loss 0.001934, train error 0.00,  test loss 4.065031, test error 50.92
# Epoch   700, train loss 0.001554, train error 0.00,  test loss 4.174623, test error 50.85
# Epoch   800, train loss 0.001291, train error 0.00,  test loss 4.266898, test error 50.83
# Epoch   900, train loss 0.001099, train error 0.00,  test loss 4.346717, test error 50.90
# Training model with 120 hidden variables
# Epoch     0, train loss 1.977006, train error 72.70,  test loss 1.919015, test error 72.30
# Epoch   100, train loss 0.052294, train error 0.00,  test loss 2.298320, test error 52.30
# Epoch   200, train loss 0.009814, train error 0.00,  test loss 2.953815, test error 52.38
# Epoch   300, train loss 0.004806, train error 0.00,  test loss 3.248250, test error 52.25
# Epoch   400, train loss 0.003048, train error 0.00,  test loss 3.439855, test error 52.40
# Epoch   500, train loss 0.002195, train error 0.00,  test loss 3.580557, test error 52.42
# Epoch   600, train loss 0.001693, train error 0.00,  test loss 3.691761, test error 52.45
# Epoch   700, train loss 0.001367, train error 0.00,  test loss 3.783357, test error 52.38
# Epoch   800, train loss 0.001140, train error 0.00,  test loss 3.861917, test error 52.45
# Epoch   900, train loss 0.000974, train error 0.00,  test loss 3.929670, test error 52.40
# Training model with 140 hidden variables
# Epoch     0, train loss 1.957727, train error 72.55,  test loss 1.884484, test error 72.65
# Epoch   100, train loss 0.035276, train error 0.00,  test loss 2.214952, test error 50.83
# Epoch   200, train loss 0.008005, train error 0.00,  test loss 2.691166, test error 50.40
# Epoch   300, train loss 0.004138, train error 0.00,  test loss 2.919750, test error 50.62
# Epoch   400, train loss 0.002690, train error 0.00,  test loss 3.070509, test error 50.50
# Epoch   500, train loss 0.001960, train error 0.00,  test loss 3.183337, test error 50.50
# Epoch   600, train loss 0.001525, train error 0.00,  test loss 3.272462, test error 50.53
# Epoch   700, train loss 0.001239, train error 0.00,  test loss 3.347276, test error 50.47
# Epoch   800, train loss 0.001038, train error 0.00,  test loss 3.410836, test error 50.42
# Epoch   900, train loss 0.000890, train error 0.00,  test loss 3.466769, test error 50.38
# Training model with 160 hidden variables
# Epoch     0, train loss 1.932706, train error 70.53,  test loss 1.862156, test error 70.38
# Epoch   100, train loss 0.026810, train error 0.00,  test loss 2.189975, test error 48.95
# Epoch   200, train loss 0.006937, train error 0.00,  test loss 2.607697, test error 49.00
# Epoch   300, train loss 0.003672, train error 0.00,  test loss 2.813302, test error 49.03
# Epoch   400, train loss 0.002416, train error 0.00,  test loss 2.952502, test error 49.15
# Epoch   500, train loss 0.001773, train error 0.00,  test loss 3.056355, test error 49.17
# Epoch   600, train loss 0.001386, train error 0.00,  test loss 3.140540, test error 49.28
# Epoch   700, train loss 0.001130, train error 0.00,  test loss 3.209906, test error 49.33
# Epoch   800, train loss 0.000949, train error 0.00,  test loss 3.268492, test error 49.28
# Epoch   900, train loss 0.000815, train error 0.00,  test loss 3.319949, test error 49.22
# Training model with 180 hidden variables
# Epoch     0, train loss 1.920982, train error 70.65,  test loss 1.852088, test error 72.28
# Epoch   100, train loss 0.024405, train error 0.00,  test loss 2.053202, test error 48.83
# Epoch   200, train loss 0.006609, train error 0.00,  test loss 2.407012, test error 48.33
# Epoch   300, train loss 0.003538, train error 0.00,  test loss 2.583175, test error 48.50
# Epoch   400, train loss 0.002341, train error 0.00,  test loss 2.703398, test error 48.53
# Epoch   500, train loss 0.001723, train error 0.00,  test loss 2.791854, test error 48.47
# Epoch   600, train loss 0.001349, train error 0.00,  test loss 2.863143, test error 48.28
# Epoch   700, train loss 0.001101, train error 0.00,  test loss 2.921906, test error 48.33
# Epoch   800, train loss 0.000926, train error 0.00,  test loss 2.972831, test error 48.33
# Epoch   900, train loss 0.000796, train error 0.00,  test loss 3.016790, test error 48.25
# Training model with 200 hidden variables
# Epoch     0, train loss 1.913620, train error 70.88,  test loss 1.837972, test error 71.07
# Epoch   100, train loss 0.021686, train error 0.00,  test loss 1.970890, test error 46.78
# Epoch   200, train loss 0.006176, train error 0.00,  test loss 2.273035, test error 46.42
# Epoch   300, train loss 0.003352, train error 0.00,  test loss 2.428891, test error 46.53
# Epoch   400, train loss 0.002237, train error 0.00,  test loss 2.534480, test error 46.50
# Epoch   500, train loss 0.001651, train error 0.00,  test loss 2.613950, test error 46.53
# Epoch   600, train loss 0.001297, train error 0.00,  test loss 2.677850, test error 46.65
# Epoch   700, train loss 0.001061, train error 0.00,  test loss 2.730890, test error 46.60
# Epoch   800, train loss 0.000893, train error 0.00,  test loss 2.776129, test error 46.50
# Epoch   900, train loss 0.000769, train error 0.00,  test loss 2.816015, test error 46.50
# Training model with 250 hidden variables
# Epoch     0, train loss 1.896631, train error 69.68,  test loss 1.817931, test error 71.90
# Epoch   100, train loss 0.017216, train error 0.00,  test loss 1.972172, test error 49.47
# Epoch   200, train loss 0.005349, train error 0.00,  test loss 2.238036, test error 49.08
# Epoch   300, train loss 0.002973, train error 0.00,  test loss 2.378119, test error 48.97
# Epoch   400, train loss 0.002006, train error 0.00,  test loss 2.472953, test error 48.97
# Epoch   500, train loss 0.001493, train error 0.00,  test loss 2.545174, test error 48.95
# Epoch   600, train loss 0.001178, train error 0.00,  test loss 2.603375, test error 48.97
# Epoch   700, train loss 0.000967, train error 0.00,  test loss 2.652338, test error 48.90
# Epoch   800, train loss 0.000817, train error 0.00,  test loss 2.694677, test error 48.85
# Epoch   900, train loss 0.000705, train error 0.00,  test loss 2.731421, test error 48.83
# Training model with 300 hidden variables
# Epoch     0, train loss 1.888229, train error 67.82,  test loss 1.805058, test error 69.35
# Epoch   100, train loss 0.014652, train error 0.00,  test loss 1.833343, test error 46.42
# Epoch   200, train loss 0.004840, train error 0.00,  test loss 2.047341, test error 46.03
# Epoch   300, train loss 0.002732, train error 0.00,  test loss 2.166615, test error 46.17
# Epoch   400, train loss 0.001860, train error 0.00,  test loss 2.246252, test error 45.95
# Epoch   500, train loss 0.001392, train error 0.00,  test loss 2.308125, test error 45.95
# Epoch   600, train loss 0.001102, train error 0.00,  test loss 2.357455, test error 45.95
# Epoch   700, train loss 0.000907, train error 0.00,  test loss 2.399404, test error 46.00
# Epoch   800, train loss 0.000768, train error 0.00,  test loss 2.435718, test error 45.95
# Epoch   900, train loss 0.000663, train error 0.00,  test loss 2.467525, test error 45.92
# Training model with 400 hidden variables
# Epoch     0, train loss 1.909400, train error 69.20,  test loss 1.830081, test error 69.40
# Epoch   100, train loss 0.011622, train error 0.00,  test loss 1.779017, test error 45.55
# Epoch   200, train loss 0.004132, train error 0.00,  test loss 1.957570, test error 45.67
# Epoch   300, train loss 0.002398, train error 0.00,  test loss 2.059064, test error 45.58
# Epoch   400, train loss 0.001652, train error 0.00,  test loss 2.128044, test error 45.42
# Epoch   500, train loss 0.001246, train error 0.00,  test loss 2.181236, test error 45.42
# Epoch   600, train loss 0.000993, train error 0.00,  test loss 2.224336, test error 45.47
# Epoch   700, train loss 0.000820, train error 0.00,  test loss 2.260673, test error 45.62
# Epoch   800, train loss 0.000696, train error 0.00,  test loss 2.292348, test error 45.60
# Epoch   900, train loss 0.000603, train error 0.00,  test loss 2.320180, test error 45.70

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
