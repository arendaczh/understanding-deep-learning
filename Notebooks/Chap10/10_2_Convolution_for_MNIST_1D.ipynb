# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-_g4v025_
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-_g4v025_
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.1.1)
# Requirement already satisfied: matplotlib in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (3.9.2)
# Requirement already satisfied: scipy in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2),
nn.ReLU(),
nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2),
nn.ReLU(),
nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2),
nn.Flatten(),
nn.Linear(60, 10)
)

print(model)
# Out:
# Sequential(
#   (0): Conv1d(1, 15, kernel_size=(3,), stride=(2,))
#   (1): ReLU()
#   (2): Conv1d(15, 15, kernel_size=(3,), stride=(2,))
#   (3): ReLU()
#   (4): Conv1d(15, 15, kernel_size=(3,), stride=(2,))
#   (5): Flatten(start_dim=1, end_dim=-1)
#   (6): Linear(in_features=60, out_features=10, bias=True)
# )

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.942792, train error 74.53,  val loss 1.956023, percent error 75.40
# Epoch     1, train loss 1.444115, train error 58.30,  val loss 1.447355, percent error 60.90
# Epoch     2, train loss 1.288750, train error 51.20,  val loss 1.303429, percent error 53.70
# Epoch     3, train loss 1.194344, train error 49.80,  val loss 1.234662, percent error 53.80
# Epoch     4, train loss 1.090231, train error 42.03,  val loss 1.107244, percent error 44.00
# Epoch     5, train loss 0.955496, train error 38.38,  val loss 0.983540, percent error 40.70
# Epoch     6, train loss 0.752984, train error 29.82,  val loss 0.775536, percent error 29.80
# Epoch     7, train loss 0.713465, train error 28.10,  val loss 0.739052, percent error 29.80
# Epoch     8, train loss 0.631368, train error 23.38,  val loss 0.691049, percent error 25.60
# Epoch     9, train loss 0.567035, train error 21.22,  val loss 0.625328, percent error 22.70
# Epoch    10, train loss 0.654174, train error 24.00,  val loss 0.750534, percent error 26.90
# Epoch    11, train loss 0.503625, train error 19.38,  val loss 0.600631, percent error 20.80
# Epoch    12, train loss 0.433631, train error 16.43,  val loss 0.544428, percent error 20.30
# Epoch    13, train loss 0.373295, train error 13.47,  val loss 0.485601, percent error 18.00
# Epoch    14, train loss 0.390001, train error 13.85,  val loss 0.493460, percent error 17.10
# Epoch    15, train loss 0.299207, train error 10.85,  val loss 0.387770, percent error 13.90
# Epoch    16, train loss 0.330289, train error 10.95,  val loss 0.453288, percent error 15.10
# Epoch    17, train loss 0.267637, train error 9.47,  val loss 0.410588, percent error 14.70
# Epoch    18, train loss 0.241693, train error 8.70,  val loss 0.375879, percent error 13.10
# Epoch    19, train loss 0.238999, train error 8.53,  val loss 0.355425, percent error 13.00
# Epoch    20, train loss 0.180036, train error 5.97,  val loss 0.302964, percent error 10.70
# Epoch    21, train loss 0.150390, train error 4.88,  val loss 0.278507, percent error 9.50
# Epoch    22, train loss 0.155023, train error 5.45,  val loss 0.300334, percent error 10.70
# Epoch    23, train loss 0.143891, train error 4.50,  val loss 0.293475, percent error 10.10
# Epoch    24, train loss 0.138837, train error 4.75,  val loss 0.284531, percent error 9.70
# Epoch    25, train loss 0.139468, train error 4.78,  val loss 0.282727, percent error 10.30
# Epoch    26, train loss 0.136046, train error 4.43,  val loss 0.301630, percent error 10.50
# Epoch    27, train loss 0.122135, train error 4.28,  val loss 0.283764, percent error 10.10
# Epoch    28, train loss 0.116259, train error 3.68,  val loss 0.277307, percent error 10.40
# Epoch    29, train loss 0.128205, train error 4.70,  val loss 0.297056, percent error 10.20
# Epoch    30, train loss 0.129175, train error 4.78,  val loss 0.300958, percent error 9.10
# Epoch    31, train loss 0.109816, train error 3.78,  val loss 0.275819, percent error 9.70
# Epoch    32, train loss 0.110931, train error 3.88,  val loss 0.279583, percent error 9.80
# Epoch    33, train loss 0.110405, train error 3.88,  val loss 0.309045, percent error 11.00
# Epoch    34, train loss 0.106103, train error 3.50,  val loss 0.298297, percent error 10.10
# Epoch    35, train loss 0.097857, train error 3.32,  val loss 0.303113, percent error 9.80
# Epoch    36, train loss 0.094059, train error 2.93,  val loss 0.297879, percent error 9.70
# Epoch    37, train loss 0.113867, train error 3.97,  val loss 0.318956, percent error 9.70
# Epoch    38, train loss 0.111663, train error 4.20,  val loss 0.322264, percent error 10.50
# Epoch    39, train loss 0.093232, train error 3.07,  val loss 0.337130, percent error 10.20
# Epoch    40, train loss 0.076995, train error 2.50,  val loss 0.286994, percent error 9.10
# Epoch    41, train loss 0.075965, train error 2.50,  val loss 0.309867, percent error 9.90
# Epoch    42, train loss 0.071013, train error 2.32,  val loss 0.292129, percent error 9.00
# Epoch    43, train loss 0.067975, train error 2.00,  val loss 0.293077, percent error 9.30
# Epoch    44, train loss 0.065441, train error 1.82,  val loss 0.292491, percent error 9.30
# Epoch    45, train loss 0.067580, train error 2.28,  val loss 0.303382, percent error 9.10
# Epoch    46, train loss 0.061132, train error 1.88,  val loss 0.297202, percent error 9.20
# Epoch    47, train loss 0.063213, train error 1.78,  val loss 0.307128, percent error 9.70
# Epoch    48, train loss 0.069689, train error 2.15,  val loss 0.339008, percent error 10.30
# Epoch    49, train loss 0.061761, train error 1.65,  val loss 0.309083, percent error 9.80
# Epoch    50, train loss 0.057723, train error 1.82,  val loss 0.307920, percent error 9.50
# Epoch    51, train loss 0.060469, train error 1.80,  val loss 0.320304, percent error 9.40
# Epoch    52, train loss 0.058016, train error 1.75,  val loss 0.319575, percent error 9.30
# Epoch    53, train loss 0.056748, train error 1.75,  val loss 0.325721, percent error 9.50
# Epoch    54, train loss 0.056531, train error 1.47,  val loss 0.332222, percent error 9.80
# Epoch    55, train loss 0.065637, train error 2.15,  val loss 0.365695, percent error 10.00
# Epoch    56, train loss 0.052295, train error 1.50,  val loss 0.326060, percent error 9.50
# Epoch    57, train loss 0.050614, train error 1.38,  val loss 0.324779, percent error 9.70
# Epoch    58, train loss 0.051856, train error 1.45,  val loss 0.340383, percent error 10.00
# Epoch    59, train loss 0.051081, train error 1.45,  val loss 0.348513, percent error 10.10
# Epoch    60, train loss 0.045653, train error 1.07,  val loss 0.339392, percent error 9.60
# Epoch    61, train loss 0.046235, train error 1.22,  val loss 0.333427, percent error 9.70
# Epoch    62, train loss 0.046078, train error 0.97,  val loss 0.348555, percent error 9.90
# Epoch    63, train loss 0.044108, train error 1.05,  val loss 0.340682, percent error 10.00
# Epoch    64, train loss 0.044495, train error 0.97,  val loss 0.347707, percent error 9.70
# Epoch    65, train loss 0.043495, train error 1.05,  val loss 0.341739, percent error 9.50
# Epoch    66, train loss 0.041838, train error 0.97,  val loss 0.344720, percent error 9.50
# Epoch    67, train loss 0.041223, train error 0.93,  val loss 0.346172, percent error 9.60
# Epoch    68, train loss 0.041339, train error 0.93,  val loss 0.349898, percent error 9.90
# Epoch    69, train loss 0.041042, train error 0.78,  val loss 0.353634, percent error 9.90
# Epoch    70, train loss 0.040150, train error 0.90,  val loss 0.350266, percent error 9.90
# Epoch    71, train loss 0.039902, train error 0.85,  val loss 0.358602, percent error 10.10
# Epoch    72, train loss 0.039164, train error 0.85,  val loss 0.352547, percent error 9.70
# Epoch    73, train loss 0.039416, train error 0.80,  val loss 0.360920, percent error 9.60
# Epoch    74, train loss 0.038886, train error 0.85,  val loss 0.358159, percent error 9.50
# Epoch    75, train loss 0.039057, train error 0.80,  val loss 0.364980, percent error 9.80
# Epoch    76, train loss 0.038347, train error 0.80,  val loss 0.361332, percent error 9.80
# Epoch    77, train loss 0.037191, train error 0.72,  val loss 0.361610, percent error 9.90
# Epoch    78, train loss 0.036329, train error 0.68,  val loss 0.367646, percent error 9.80
# Epoch    79, train loss 0.038368, train error 0.75,  val loss 0.368576, percent error 9.70
# Epoch    80, train loss 0.035564, train error 0.65,  val loss 0.368255, percent error 10.00
# Epoch    81, train loss 0.035264, train error 0.62,  val loss 0.366081, percent error 9.90
# Epoch    82, train loss 0.035120, train error 0.70,  val loss 0.369795, percent error 9.80
# Epoch    83, train loss 0.035271, train error 0.62,  val loss 0.366058, percent error 9.70
# Epoch    84, train loss 0.034741, train error 0.62,  val loss 0.371315, percent error 9.90
# Epoch    85, train loss 0.034343, train error 0.65,  val loss 0.371547, percent error 10.10
# Epoch    86, train loss 0.034284, train error 0.62,  val loss 0.371090, percent error 9.90
# Epoch    87, train loss 0.033976, train error 0.60,  val loss 0.374110, percent error 10.10
# Epoch    88, train loss 0.034175, train error 0.62,  val loss 0.378227, percent error 9.80
# Epoch    89, train loss 0.034085, train error 0.60,  val loss 0.374282, percent error 10.00
# Epoch    90, train loss 0.034018, train error 0.50,  val loss 0.378290, percent error 10.10
# Epoch    91, train loss 0.033587, train error 0.50,  val loss 0.373038, percent error 9.60
# Epoch    92, train loss 0.033019, train error 0.53,  val loss 0.377944, percent error 10.10
# Epoch    93, train loss 0.033097, train error 0.60,  val loss 0.376773, percent error 10.00
# Epoch    94, train loss 0.032835, train error 0.57,  val loss 0.378120, percent error 10.00
# Epoch    95, train loss 0.033081, train error 0.57,  val loss 0.379281, percent error 10.00
# Epoch    96, train loss 0.032816, train error 0.50,  val loss 0.380454, percent error 10.00
# Epoch    97, train loss 0.032429, train error 0.57,  val loss 0.379755, percent error 9.90
# Epoch    98, train loss 0.033057, train error 0.57,  val loss 0.380032, percent error 10.00
# Epoch    99, train loss 0.032307, train error 0.57,  val loss 0.382846, percent error 10.00
