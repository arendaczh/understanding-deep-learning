# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-g3yrjexg
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-g3yrjexg
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.1.1)
# Requirement already satisfied: matplotlib in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (3.9.2)
# Requirement already satisfied: scipy in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /home/arendaczh/Desktop/TCS-3/AI/udlbook/Notebooks/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x)
    h2 = h1 + self.linear2(h1.relu())
    h3 = h2 + self.linear3(h2.relu())
    return self.linear4(h3.relu())

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.642293, train error 65.05,  val loss 1.694695, percent error 69.60
# Epoch     1, train loss 1.377822, train error 50.97,  val loss 1.511427, percent error 59.60
# Epoch     2, train loss 1.163851, train error 42.75,  val loss 1.384038, percent error 55.00
# Epoch     3, train loss 1.051116, train error 39.00,  val loss 1.322648, percent error 48.90
# Epoch     4, train loss 0.892994, train error 32.62,  val loss 1.246040, percent error 47.50
# Epoch     5, train loss 0.822231, train error 29.12,  val loss 1.230109, percent error 47.20
# Epoch     6, train loss 0.754933, train error 27.40,  val loss 1.193498, percent error 43.80
# Epoch     7, train loss 0.683924, train error 24.85,  val loss 1.193215, percent error 42.70
# Epoch     8, train loss 0.540994, train error 18.95,  val loss 1.153936, percent error 41.20
# Epoch     9, train loss 0.508848, train error 18.10,  val loss 1.162079, percent error 41.90
# Epoch    10, train loss 0.479942, train error 16.95,  val loss 1.217506, percent error 41.50
# Epoch    11, train loss 0.371044, train error 12.38,  val loss 1.155114, percent error 36.20
# Epoch    12, train loss 0.357186, train error 11.95,  val loss 1.188957, percent error 38.60
# Epoch    13, train loss 0.289604, train error 9.10,  val loss 1.198906, percent error 39.10
# Epoch    14, train loss 0.269963, train error 9.35,  val loss 1.280408, percent error 37.60
# Epoch    15, train loss 0.289940, train error 10.57,  val loss 1.397872, percent error 37.90
# Epoch    16, train loss 0.206000, train error 6.75,  val loss 1.294639, percent error 36.50
# Epoch    17, train loss 0.208095, train error 6.70,  val loss 1.331878, percent error 36.00
# Epoch    18, train loss 0.171793, train error 5.35,  val loss 1.488963, percent error 38.20
# Epoch    19, train loss 0.153137, train error 5.12,  val loss 1.526062, percent error 38.70
# Epoch    20, train loss 0.061866, train error 0.88,  val loss 1.369511, percent error 34.30
# Epoch    21, train loss 0.042077, train error 0.22,  val loss 1.367769, percent error 34.60
# Epoch    22, train loss 0.032712, train error 0.10,  val loss 1.391541, percent error 33.40
# Epoch    23, train loss 0.027854, train error 0.07,  val loss 1.421031, percent error 33.90
# Epoch    24, train loss 0.022603, train error 0.03,  val loss 1.465866, percent error 33.20
# Epoch    25, train loss 0.020069, train error 0.00,  val loss 1.484489, percent error 32.90
# Epoch    26, train loss 0.017867, train error 0.00,  val loss 1.504887, percent error 33.20
# Epoch    27, train loss 0.015943, train error 0.00,  val loss 1.520926, percent error 33.90
# Epoch    28, train loss 0.014403, train error 0.00,  val loss 1.540702, percent error 33.30
# Epoch    29, train loss 0.013392, train error 0.00,  val loss 1.570001, percent error 33.60
# Epoch    30, train loss 0.012123, train error 0.00,  val loss 1.588209, percent error 33.90
# Epoch    31, train loss 0.011214, train error 0.00,  val loss 1.598344, percent error 33.60
# Epoch    32, train loss 0.010413, train error 0.00,  val loss 1.620735, percent error 33.70
# Epoch    33, train loss 0.009750, train error 0.00,  val loss 1.643078, percent error 33.90
# Epoch    34, train loss 0.009262, train error 0.00,  val loss 1.639981, percent error 33.70
# Epoch    35, train loss 0.008547, train error 0.00,  val loss 1.660956, percent error 33.60
# Epoch    36, train loss 0.008066, train error 0.00,  val loss 1.669588, percent error 33.80
# Epoch    37, train loss 0.007646, train error 0.00,  val loss 1.686003, percent error 34.00
# Epoch    38, train loss 0.007236, train error 0.00,  val loss 1.697007, percent error 33.90
# Epoch    39, train loss 0.006877, train error 0.00,  val loss 1.710837, percent error 34.10
# Epoch    40, train loss 0.006699, train error 0.00,  val loss 1.713775, percent error 33.90
# Epoch    41, train loss 0.006528, train error 0.00,  val loss 1.721337, percent error 34.00
# Epoch    42, train loss 0.006379, train error 0.00,  val loss 1.727473, percent error 33.80
# Epoch    43, train loss 0.006240, train error 0.00,  val loss 1.730482, percent error 34.00
# Epoch    44, train loss 0.006104, train error 0.00,  val loss 1.735364, percent error 33.60
# Epoch    45, train loss 0.005974, train error 0.00,  val loss 1.743405, percent error 33.90
# Epoch    46, train loss 0.005850, train error 0.00,  val loss 1.746636, percent error 33.80
# Epoch    47, train loss 0.005729, train error 0.00,  val loss 1.752883, percent error 33.90
# Epoch    48, train loss 0.005616, train error 0.00,  val loss 1.757098, percent error 33.70
# Epoch    49, train loss 0.005503, train error 0.00,  val loss 1.761484, percent error 33.70
# Epoch    50, train loss 0.005399, train error 0.00,  val loss 1.767367, percent error 33.80
# Epoch    51, train loss 0.005300, train error 0.00,  val loss 1.772686, percent error 34.10
# Epoch    52, train loss 0.005188, train error 0.00,  val loss 1.776622, percent error 33.80
# Epoch    53, train loss 0.005093, train error 0.00,  val loss 1.779044, percent error 33.90
# Epoch    54, train loss 0.005001, train error 0.00,  val loss 1.785353, percent error 33.60
# Epoch    55, train loss 0.004909, train error 0.00,  val loss 1.787422, percent error 33.80
# Epoch    56, train loss 0.004823, train error 0.00,  val loss 1.791661, percent error 33.80
# Epoch    57, train loss 0.004735, train error 0.00,  val loss 1.797394, percent error 33.90
# Epoch    58, train loss 0.004655, train error 0.00,  val loss 1.800263, percent error 33.90
# Epoch    59, train loss 0.004578, train error 0.00,  val loss 1.805459, percent error 33.80
# Epoch    60, train loss 0.004534, train error 0.00,  val loss 1.807024, percent error 33.70
# Epoch    61, train loss 0.004495, train error 0.00,  val loss 1.809633, percent error 34.00
# Epoch    62, train loss 0.004457, train error 0.00,  val loss 1.811946, percent error 33.80
# Epoch    63, train loss 0.004420, train error 0.00,  val loss 1.812470, percent error 33.70
# Epoch    64, train loss 0.004383, train error 0.00,  val loss 1.815594, percent error 33.70
# Epoch    65, train loss 0.004348, train error 0.00,  val loss 1.817092, percent error 33.70
# Epoch    66, train loss 0.004313, train error 0.00,  val loss 1.819273, percent error 33.60
# Epoch    67, train loss 0.004278, train error 0.00,  val loss 1.821262, percent error 33.90
# Epoch    68, train loss 0.004244, train error 0.00,  val loss 1.823026, percent error 34.00
# Epoch    69, train loss 0.004211, train error 0.00,  val loss 1.824660, percent error 33.90
# Epoch    70, train loss 0.004178, train error 0.00,  val loss 1.826821, percent error 33.80
# Epoch    71, train loss 0.004145, train error 0.00,  val loss 1.828679, percent error 33.70
# Epoch    72, train loss 0.004113, train error 0.00,  val loss 1.829872, percent error 33.60
# Epoch    73, train loss 0.004082, train error 0.00,  val loss 1.832082, percent error 33.90
# Epoch    74, train loss 0.004050, train error 0.00,  val loss 1.834131, percent error 33.60
# Epoch    75, train loss 0.004018, train error 0.00,  val loss 1.835629, percent error 33.60
# Epoch    76, train loss 0.003989, train error 0.00,  val loss 1.837550, percent error 33.70
# Epoch    77, train loss 0.003959, train error 0.00,  val loss 1.838709, percent error 33.70
# Epoch    78, train loss 0.003929, train error 0.00,  val loss 1.841076, percent error 33.80
# Epoch    79, train loss 0.003901, train error 0.00,  val loss 1.842717, percent error 33.60
# Epoch    80, train loss 0.003885, train error 0.00,  val loss 1.843988, percent error 33.70
# Epoch    81, train loss 0.003871, train error 0.00,  val loss 1.844478, percent error 33.70
# Epoch    82, train loss 0.003856, train error 0.00,  val loss 1.845692, percent error 33.90
# Epoch    83, train loss 0.003842, train error 0.00,  val loss 1.846572, percent error 33.90
# Epoch    84, train loss 0.003828, train error 0.00,  val loss 1.847172, percent error 33.80
# Epoch    85, train loss 0.003814, train error 0.00,  val loss 1.848040, percent error 33.80
# Epoch    86, train loss 0.003801, train error 0.00,  val loss 1.849090, percent error 33.70
# Epoch    87, train loss 0.003787, train error 0.00,  val loss 1.850160, percent error 33.80
# Epoch    88, train loss 0.003773, train error 0.00,  val loss 1.850802, percent error 33.80
# Epoch    89, train loss 0.003760, train error 0.00,  val loss 1.851573, percent error 33.90
# Epoch    90, train loss 0.003746, train error 0.00,  val loss 1.852406, percent error 33.80
# Epoch    91, train loss 0.003733, train error 0.00,  val loss 1.853451, percent error 33.70
# Epoch    92, train loss 0.003720, train error 0.00,  val loss 1.854463, percent error 34.00
# Epoch    93, train loss 0.003706, train error 0.00,  val loss 1.855563, percent error 33.60
# Epoch    94, train loss 0.003694, train error 0.00,  val loss 1.855915, percent error 33.90
# Epoch    95, train loss 0.003680, train error 0.00,  val loss 1.856727, percent error 33.90
# Epoch    96, train loss 0.003667, train error 0.00,  val loss 1.857741, percent error 33.70
# Epoch    97, train loss 0.003655, train error 0.00,  val loss 1.858413, percent error 33.80
# Epoch    98, train loss 0.003642, train error 0.00,  val loss 1.859591, percent error 33.80
# Epoch    99, train loss 0.003629, train error 0.00,  val loss 1.860315, percent error 33.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
